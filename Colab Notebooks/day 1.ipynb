# %% [markdown]
# # **1**

# %%
a = "sakib"
b = 10
c = 20

# %%
print("hello world")
# Out:
# hello world

# %%
print(a)
# Out:
# sakib

# %%
a
# Out:
# 'sakib'

# %%
print("the value of a is",a)
# Out:
# the value of a is sakib

# %%
print("text1","text2",sep=" & ",end=" | ")
# Out:
# text1 & text2 |

# %% [markdown]
# # **2**

# %%
x = input("1st-")
y = input("2nd-")
# Out:
# 1st-10
# 2nd-20

# %%
print(x + y)
# Out:
# 1020

# %%
x = int(input("1st-"))
y = int(input("2nd-"))
# Out:
# 1st-10
# 2nd-20

# %%
print(x+y)
# Out:
# 30
