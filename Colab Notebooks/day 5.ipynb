# %% [markdown]
# # **1**

# %%
x = 20
y = 10

# %%
print(x+y)
print(x-y)
print(x*y)
print(x/y)
# Out:
# 30
# 10
# 200
# 2.0

# %%
print(x**y) # same as x to the power y
# Out:
# 10240000000000

# %%
print(x//y) #ভাগফল
# Out:
# 2

# %%
print(x%y) #ভাগশেষ
# Out:
# 0

# %% [markdown]
# # **2**

# %%
a = 1001
b = a
c = 1001

# %%
print(a is b)
# Out:
# True

# %%
print(a is c)
# Out:
# False

# %%
print(a == c)
# Out:
# True

# %% [markdown]
# **beacase**>>>>
#
# 1.   "is" ,  means memory adresss of a = memory adress of c
# 2.  "==',   means value of a = value of c

# %%
print(id(a))
print(id(b))   #memory adress
print(id(c))
# Out:
# 135720972589072
# 135720972589072
# 135720972587024

# %%
a is not c
# Out:
# True

# %% [markdown]
# # **3**

# %%
l = [1,2,3,4,6,7]
1 in l
# Out:
# True

# %%
0 in l
# Out:
# False

# %%
 0 not in l
# Out:
# True

# %%
st = 'my name is sakib'
'my' in st
# Out:
# True

# %%
'My' in st
# Out:
# False

# %%
d = 3

# %%
d > 10 and d < 5
# Out:
# False

# %%
d < 10 and d < 5
# Out:
# True

# %%
d > 10 or d < 5
# Out:
# True

# %% [markdown]
# # **4**

# %%
a = 1
b = 2
if a == b:
  print('a is equal to b')
else:
  print('a is not equal to b')
# Out:
# a is not equal to b

# %%
a = 1
b = 2
if a == b:
  print('a is equal to b')
elif a < b:
  print('b is greater than a')
else:
  print('a is not equal to b')
# Out:
# b is greater than a

# %% [markdown]
# # **5**
