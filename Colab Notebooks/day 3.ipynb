# %% [markdown]
# # **1**

# %%
# Numeric data
x = 10 #int
y = 10.5 #float
z = 10 + 5j #imaginary

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
type(z)
# Out:
# complex

# %%
isinstance(z,complex)
# Out:
# True

# %% [markdown]
# # **2**

# %%
n = float(x)

# %%
n
# Out:
# 10.0

# %%
a = complex(x)

# %%
a
# Out:
# (10+0j)

# %%
a = float(a)#we can't change complex number into a float
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3508272940.py in <cell line: 0>()
# ----> 1 a = float(a)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
a = int(a)#we can't change complex number into a int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3452485011.py in <cell line: 0>()
# ----> 1 a = int(a)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %% [markdown]
# # **3**

# %%
b = complex(input("enter a complex number-"))
# Out:
# enter a complex number-1

# %%
b
# Out:
# (1+0j)

# %%
c = True

# %%
type(c)
# Out:
# bool
