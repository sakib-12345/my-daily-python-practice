# %% [markdown]
# # **1**

# %%
import pandas as pd

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
l = ["c1","c2","c3","c4"]

# %%
a = pd.DataFrame(l)

# %%
a
# Out:
#     0
# 0  c1
# 1  c2
# 2  c3
# 3  c4

# %%
a.shape
# Out:
# (4, 1)

# %%
a = pd.DataFrame(l, columns = ["title"])
a
# Out:
#   title
# 0    c1
# 1    c2
# 2    c3
# 3    c4

# %%
a = pd.DataFrame(l, columns = ["title"], index = ["a","b","c","d"])
a
# Out:
#   title
# a    c1
# b    c2
# c    c3
# d    c4

# %%
l2 = ["c5","c6","c7","c8"]

# %%
import pandas as pd

b = pd.DataFrame(zip(l,l2), columns = ["title","title2"], index = ["a","b","c","d"])
b
# Out:
#   title title2
# a    c1     c5
# b    c2     c6
# c    c3     c7
# d    c4     c8

# %%
city = [["sakib","20"],["tahmid","12"],["hossain","-"]]

# %%
df = pd.DataFrame(city, columns = ["name","age"])
df
# Out:
#       name age
# 0    sakib  20
# 1   tahmid  12
# 2  hossain   -

# %%
dic = {
    "name" : ["sakib","tahmid","hossain"],
    "password" : ["12345","67453","14678"]
}
df3 = pd.DataFrame(dic)
df3
# Out:
#       name password
# 0    sakib    12345
# 1   tahmid    67453
# 2  hossain    14678

# %% [markdown]
# # **2**

# %%
import pandas as pd

# %%
path = "/content/drive/MyDrive/test/test data 2.csv"

# %%
df4 = pd.read_csv(path)
df4
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.05     37.37                27.0       3885.0           661.0
# 1     -118.30     34.26                43.0       1510.0           310.0
# 2     -117.81     33.78                27.0       3589.0           507.0
# 3     -118.36     33.82                28.0         67.0            15.0
# 4     -119.67     36.33                19.0       1241.0           244.0
# 5     -119.56     36.51                37.0       1018.0           213.0
# 6     -121.43     38.63                43.0       1009.0           225.0
# 7     -120.65     35.48                19.0       2310.0           471.0
# 8     -122.84     38.40                15.0       3080.0           617.0
# 9     -118.02     34.08                31.0       2402.0           632.0
# 10    -118.24     33.98                45.0        972.0           249.0
# 11    -119.12     35.85                37.0        736.0           166.0
# ...

# %%
df4.head(5)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df4.tail(5)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16    -120.81     37.53                15.0        570.0           123.0
# 17    -121.20     38.69                26.0       3077.0           607.0
# 18    -118.88     34.21                26.0       1590.0           196.0
# 19    -122.59     38.01                35.0       8814.0          1307.0
# 20    -122.15     37.75                40.0       1445.0           256.0
#
#     population  households  median_income  median_house_value
# 16       189.0       107.0         1.8750            181300.0
# 17      1603.0       595.0         2.7174            137500.0
# 18       654.0       199.0         6.5851            300000.0
# 19      3450.0      1258.0         6.1724            414300.0
# 20       849.0       255.0         3.8913            126300.0

# %%
df4.shape
# Out:
# (21, 9)

# %%
df4.values
# Out:
# array([[-1.2205e+02,  3.7370e+01,  2.7000e+01,  3.8850e+03,  6.6100e+02,
#          1.5370e+03,  6.0600e+02,  6.6085e+00,  3.4470e+05],
#        [-1.1830e+02,  3.4260e+01,  4.3000e+01,  1.5100e+03,  3.1000e+02,
#          8.0900e+02,  2.7700e+02,  3.5990e+00,  1.7650e+05],
#        [-1.1781e+02,  3.3780e+01,  2.7000e+01,  3.5890e+03,  5.0700e+02,
#          1.4840e+03,  4.9500e+02,  5.7934e+00,  2.7050e+05],
#        [-1.1836e+02,  3.3820e+01,  2.8000e+01,  6.7000e+01,  1.5000e+01,
#          4.9000e+01,  1.1000e+01,  6.1359e+00,  3.3000e+05],
#        [-1.1967e+02,  3.6330e+01,  1.9000e+01,  1.2410e+03,  2.4400e+02,
#          8.5000e+02,  2.3700e+02,  2.9375e+00,  8.1700e+04],
#        [-1.1956e+02,  3.6510e+01,  3.7000e+01,  1.0180e+03,  2.1300e+02,
#          6.6300e+02,  2.0400e+02,  1.6635e+00,  6.7000e+04],
#        [-1.2143e+02,  3.8630e+01,  4.3000e+01,  1.0090e+03,  2.2500e+02,
#          6.0400e+02,  2.1800e+02,  1.6641e+00,  6.7000e+04],
# ...

# %%
df4.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df4.total_rooms # if (total rooms) there is space between them, then write:  df4[[total rooms]]
# Out:
# 0     3885.0
# 1     1510.0
# 2     3589.0
# 3       67.0
# 4     1241.0
# 5     1018.0
# 6     1009.0
# 7     2310.0
# 8     3080.0
# 9     2402.0
# 10     972.0
# 11     736.0
# 12    1089.0
# 13    3936.0
# 14    2097.0
# 15     161.0
# 16     570.0
# 17    3077.0
# 18    1590.0
# 19    8814.0
# 20    1445.0
# Name: total_rooms, dtype: float64

# %%
df4.total_rooms.head(4)
# Out:
# 0    3885.0
# 1    1510.0
# 2    3589.0
# 3      67.0
# Name: total_rooms, dtype: float64

# %%
df4[["total_rooms","total_bedrooms"]]
# Out:
#     total_rooms  total_bedrooms
# 0        3885.0           661.0
# 1        1510.0           310.0
# 2        3589.0           507.0
# 3          67.0            15.0
# 4        1241.0           244.0
# 5        1018.0           213.0
# 6        1009.0           225.0
# 7        2310.0           471.0
# 8        3080.0           617.0
# 9        2402.0           632.0
# 10        972.0           249.0
# 11        736.0           166.0
# 12       1089.0           182.0
# 13       3936.0           694.0
# 14       2097.0           325.0
# 15        161.0            40.0
# 16        570.0           123.0
# 17       3077.0           607.0
# 18       1590.0           196.0
# 19       8814.0          1307.0
# 20       1445.0           256.0

# %%
df4[["total_rooms","total_bedrooms"]].head(4)
# Out:
#    total_rooms  total_bedrooms
# 0       3885.0           661.0
# 1       1510.0           310.0
# 2       3589.0           507.0
# 3         67.0            15.0

# %%
df4['total_rooms'].sort_values() #default small to large
# Out:
# 3       67.0
# 15     161.0
# 16     570.0
# 11     736.0
# 10     972.0
# 6     1009.0
# 5     1018.0
# 12    1089.0
# 4     1241.0
# 20    1445.0
# 1     1510.0
# 18    1590.0
# 14    2097.0
# 7     2310.0
# 9     2402.0
# 17    3077.0
# 8     3080.0
# 2     3589.0
# 0     3885.0
# 13    3936.0
# 19    8814.0
# Name: total_rooms, dtype: float64

# %%
df4['total_rooms'].sort_values(ascending=True) # also small to large
# Out:
# 3       67.0
# 15     161.0
# 16     570.0
# 11     736.0
# 10     972.0
# 6     1009.0
# 5     1018.0
# 12    1089.0
# 4     1241.0
# 20    1445.0
# 1     1510.0
# 18    1590.0
# 14    2097.0
# 7     2310.0
# 9     2402.0
# 17    3077.0
# 8     3080.0
# 2     3589.0
# 0     3885.0
# 13    3936.0
# 19    8814.0
# Name: total_rooms, dtype: float64

# %%
df4['total_rooms'].sort_values(ascending=False) # large to small
# Out:
# 19    8814.0
# 13    3936.0
# 0     3885.0
# 2     3589.0
# 8     3080.0
# 17    3077.0
# 9     2402.0
# 7     2310.0
# 14    2097.0
# 18    1590.0
# 1     1510.0
# 20    1445.0
# 4     1241.0
# 12    1089.0
# 5     1018.0
# 6     1009.0
# 10     972.0
# 11     736.0
# 16     570.0
# 15     161.0
# 3       67.0
# Name: total_rooms, dtype: float64

# %%
df4.sort_values("total_rooms",ascending=False) #df4.sort_values("total_rooms",ascending=True) small to large
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19    -122.59     38.01                35.0       8814.0          1307.0
# 13    -117.03     32.97                16.0       3936.0           694.0
# 0     -122.05     37.37                27.0       3885.0           661.0
# 2     -117.81     33.78                27.0       3589.0           507.0
# 8     -122.84     38.40                15.0       3080.0           617.0
# 17    -121.20     38.69                26.0       3077.0           607.0
# 9     -118.02     34.08                31.0       2402.0           632.0
# 7     -120.65     35.48                19.0       2310.0           471.0
# 14    -117.97     33.73                27.0       2097.0           325.0
# 18    -118.88     34.21                26.0       1590.0           196.0
# 1     -118.30     34.26                43.0       1510.0           310.0
# 20    -122.15     37.75                40.0       1445.0           256.0
# ...

# %% [markdown]
# # **3**

# %%
df4.describe()
# Out:
#         longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# count   21.000000  21.000000           21.000000    21.000000       21.000000
# mean  -119.838095  35.830476           30.190476  2123.714286      382.857143
# std      1.844499   1.945038            9.790909  1928.928359      298.071180
# min   -122.840000  32.970000           15.000000    67.000000       15.000000
# 25%   -121.430000  33.980000           26.000000  1009.000000      196.000000
# 50%   -119.560000  35.850000           28.000000  1510.000000      256.000000
# 75%   -118.240000  37.530000           37.000000  3077.000000      607.000000
# max   -117.030000  38.690000           45.000000  8814.000000     1307.000000
#
#         population   households  median_income  median_house_value
# count    21.000000    21.000000      21.000000           21.000000
# mean   1145.428571   367.333333       3.840843       193571.428571
# ...

# %%
df4['total_bedrooms'] < 200
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13    False
# 14    False
# 15     True
# 16     True
# 17    False
# 18     True
# 19    False
# 20    False
# Name: total_bedrooms, dtype: bool

# %%
df4[df4['total_bedrooms'] < 200]
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3     -118.36     33.82                28.0         67.0            15.0
# 11    -119.12     35.85                37.0        736.0           166.0
# 12    -121.93     37.25                36.0       1089.0           182.0
# 15    -117.99     33.81                42.0        161.0            40.0
# 16    -120.81     37.53                15.0        570.0           123.0
# 18    -118.88     34.21                26.0       1590.0           196.0
#
#     population  households  median_income  median_house_value
# 3         49.0        11.0         6.1359            330000.0
# 11       564.0       138.0         2.4167             58300.0
# 12       535.0       170.0         4.6900            252600.0
# 15       157.0        50.0         2.2000            153100.0
# 16       189.0       107.0         1.8750            181300.0
# 18       654.0       199.0         6.5851            300000.0

# %%
#for string value
#df4[df4['name'] == "sakib"]

# %%
#for multiple strings
#df4["name"].isin(["sakib","tahmid"])

# %%
#df4[df4["name"].isin(["sakib","tahmid"])]

# %% [markdown]
# # **not needed**

# %%
df4.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.932144            0.071410    -0.316302
# latitude            -0.932144  1.000000           -0.034137     0.214558
# housing_median_age   0.071410 -0.034137            1.000000    -0.201027
# total_rooms         -0.316302  0.214558           -0.201027     1.000000
# total_bedrooms      -0.314579  0.232074           -0.227719     0.970193
# population          -0.123498  0.054329           -0.134218     0.868169
# households          -0.309076  0.227532           -0.222168     0.970928
# median_income       -0.024199 -0.206054           -0.227916     0.473474
# median_house_value  -0.109700 -0.127545           -0.236355     0.597816
#
#                     total_bedrooms  population  households  median_income  \
# longitude                -0.314579   -0.123498   -0.309076      -0.024199
# latitude                  0.232074    0.054329    0.227532      -0.206054
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df4.corr(), annot=True)
# Out:
# <Axes: >
