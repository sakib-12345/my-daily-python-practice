# %% [markdown]
# # **1**

# %%
import sys

# %%
d = "my name is sakib"

# %%
sys.getsizeof(d)
# Out:
# 65

# %%
d.count("my")
# Out:
# 1

# %%
d.count("sakib")
# Out:
# 1

# %%
d.count("my")
# Out:
# 1

# %%
d.find("is")
# Out:
# 8

# %%
d.find("is",6,10)
# Out:
# 8

# %%
d.find("is",1,7) # -1 means there is no data between 1 to 7
# Out:
# -1

# %%
d.index("is")
# Out:
# 8

# %%
d.index("is",1,7)  #if there is no data , index func. will call it syntex eror .
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2939746593.py in <cell line: 0>()
# ----> 1 d.index("is",1,7)
#
# ValueError: substring not found

# %% [markdown]
# # **2**

# %%
d.lower() # all letter small
# Out:
# 'my name is sakib'

# %%
d.upper()# all letter capital
# Out:
# 'MY NAME IS SAKIB'

# %%
d.capitalize()# 1st letter capital
# Out:
# 'My name is sakib'

# %%
d.swapcase() # oposite letter(small letter= big letter and big letter = small letter)
# Out:
# 'MY NAME IS SAKIB'

# %%
d.title()# only the 1st letter of every word turns big letter
# Out:
# 'My Name Is Sakib'

# %%
d.islower()
d.isupper()
# Out:
# False

# %% [markdown]
# # **3**

# %%
d.split()# every word split into list
# Out:
# ['my', 'name', 'is', 'sakib']

# %%
d.split()[0]
# Out:
# 'my'

# %%
d.split()[3]
# Out:
# 'sakib'

# %%
d.center(100)
# Out:
# '                                          my name is sakib                                          '

# %%
d.replace("sakib","tahmid")
# Out:
# 'my name is tahmid'

# %% [markdown]
# # **4**

# %%
x = 10
y = 100
z = x*y
print("i have",z,"taka")
# Out:
# i have 1000 taka

# %%
print("i have {} taka".format(z))
# Out:
# i have 1000 taka
